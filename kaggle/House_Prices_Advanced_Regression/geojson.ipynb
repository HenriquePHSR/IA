# %%
import urllib.request, urllib.parse, urllib.error
import json
import ssl

# %%
def get_location(api_key, address):
    # If you have a Google Places API key, enter it here
    # api_key = 'AIzaSy___IDByT70'
    # https://developers.google.com/maps/documentation/geocoding/intro

    if api_key is False:
        api_key = 42
        serviceurl = 'http://py4e-data.dr-chuck.net/json?'
    else :
        serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'

    # Ignore SSL certificate errors
    ctx = ssl.create_default_context()
    ctx.check_hostname = False
    ctx.verify_mode = ssl.CERT_NONE

    

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    try:
        js = json.loads(data)
    except:
        js = None

    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        

    print(json.dumps(js, indent=4))

    lat = js['results'][0]['geometry']['location']['lat']
    lng = js['results'][0]['geometry']['location']['lng']
    print('lat', lat, 'lng', lng)
    location = js['results'][0]['formatted_address']
    print(location)

# %%
get_location(False, 'Gilchrist St, AMES, IOWA')
# Out:
# Retrieving http://py4e-data.dr-chuck.net/json?address=Gilchrist+St%2C+AMES%2C+IOWA&key=42
# Retrieved 2253 characters
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Gilchrist Street",
#                     "short_name": "Gilchrist St",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Ames",
#                     "short_name": "Ames",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Washington",
#                     "short_name": "Washington",
#                     "types": [
#                         "administrative_area_level_3",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Story County",
#                     "short_name": "Story County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Iowa",
#                     "short_name": "IA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "50010",
#                     "short_name": "50010",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "Gilchrist St, Ames, IA 50010, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 42.0242507,
#                         "lng": -93.61354879999999
#                     },
#                     "southwest": {
#                         "lat": 42.02283389999999,
#                         "lng": -93.6182975
#                     }
#                 },
#                 "location": {
#                     "lat": 42.0236715,
#                     "lng": -93.6161489
#                 },
#                 "location_type": "GEOMETRIC_CENTER",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 42.0248912802915,
#                         "lng": -93.61354879999999
#                     },
#                     "southwest": {
#                         "lat": 42.0221933197085,
#                         "lng": -93.6182975
#                     }
#                 }
#             },
#             "place_id": "ChIJmQ7U43hw7ocRnduemcpfZRc",
#             "types": [
#                 "route"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# lat 42.0236715 lng -93.6161489
# Gilchrist St, Ames, IA 50010, USA
